# %%
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import shutil
import os
import sys
from os import rename, listdir
import pandas as pd

# %%
# !pip install opencv-python

# %%
face_cascade1 = cv2.CascadeClassifier(
    './opencv-master/data/haarcascades/haarcascade_frontalface_default.xml')
face_cascade2 = cv2.CascadeClassifier(
    './opencv-master/data/haarcascades/haarcascade_frontalface_alt.xml')
face_cascade3 = cv2.CascadeClassifier(
    './opencv-master/data/haarcascades/haarcascade_frontalcatface.xml')
face_cascade4 = cv2.CascadeClassifier(
    './opencv-master/data/haarcascades/haarcascade_frontalcatface_extended.xml')
face_cascade5 = cv2.CascadeClassifier(
    './opencv-master/data/haarcascades/haarcascade_frontalface_alt2.xml')
face_cascade6 = cv2.CascadeClassifier(
    './opencv-master/data/haarcascades/haarcascade_frontalface_alt_tree.xml')
face_cascade7 = cv2.CascadeClassifier(
    './opencv-master/data/haarcascades/haarcascade_smile.xml')
face_cascade8=cv2.CascadeClassifier(
    './opencv-master/data/haarcascades/haarcascade_eye.xml')

# %%
image = cv2.imread('C:/Users/user/KHU/project/instagram-crawler-master3/djart/new_folder/cicapair/000008.jpg')

# %%
plt.figure(figsize=(12,8))
plt.imshow(image[:,:,::-1])

# %%
image=cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
faces=face_cascade1.detectMultiScale(image, scaleFactor=1.1, minNeighbors=5, minSize=(150, 150))

# %%
for (x,y,w,h) in faces:
    cv2.rectangle(image,(x,y),(x+w,y+h),(0,255,0),2)

cv2.rectangle(image, ((0,image.shape[0] -25)), 
              (270, image.shape[0]), (255,255,255), -1);
cv2.putText(image, "PinkWink test", (0,image.shape[0] -10), 
            cv2.FONT_HERSHEY_TRIPLEX, 0.5,  (0,0,0), 1);

plt.figure(figsize=(8,8))
plt.imshow(image, cmap='gray')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# %%
image= cv2.imread("./djart/1/000012.jpg")
plt.figure(figsize=(10,10))
plt.imshow(image[:,:,::-1])

# %%
image_gs = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
faces=face_cascade2.detectMultiScale(image, scaleFactor=1.1, minNeighbors=1, minSize=(150, 150))
print("Number of faces detected: " + str(faces.shape[0]))
# for i in a:
#     if len(i) >= 1:
#         list.append(1)
#     else if len(i) == 0:
#         list.append(0)
        
# 제품 = [a,b,c,d,e,f]
# list = [0,1,1,1,1,0]
# a = 0
# b = 1
# b,c,d,e 전부 보내는형식
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-9f10e472132e> in <module>
#       1 faces=face_cascade2.detectMultiScale(image, scaleFactor=1.1, minNeighbors=1, minSize=(150, 150))
# ----> 2 print("Number of faces detected: " + str(faces.shape[0]))
#       3 # for i in a:
#       4 #     if len(i) >= 1:
#       5 #         list.append(1)
#
# AttributeError: 'tuple' object has no attribute 'shape'

# %%
len(faces)
# Out:
# 0

# %%
for (x,y,w,h) in faces:
    cv2.rectangle(image,(x,y),(x+w,y+h),(0,255,0),2)

cv2.rectangle(image, ((0,image.shape[0] -25)), 
              (270, image.shape[0]), (255,255,255), -1);
cv2.putText(image, "PinkWink test", (0,image.shape[0] -10), 
            cv2.FONT_HERSHEY_TRIPLEX, 0.5,  (0,0,0), 1);

plt.figure(figsize=(12,12))
plt.imshow(image, cmap='gray')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# %%
shutil.move('./KakaoTalk_20190813_111005066.png','face/KakaoTalk_20190813_111005066.png')
# Out:
# 'face/KakaoTalk_20190813_111005066.png'

# %%
plt.figure(figsize=(12,8))
plt.imshow(imagetemp[:,:,::])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-116-7d408374d5ad> in <module>
#       1 plt.figure(figsize=(12,8))
# ----> 2 plt.imshow(imagetemp[:,:])
#
# TypeError: 'NoneType' object is not subscriptable

# %%
path = "./djart"
file_list = os.listdir(path)

print ("file_list: {}".format(file_list))
# Out:
# file_list: ['더마클리어마이크로약산성폼', '더마클리어마이크로워터', '더마클리어마이크로폼', '리프트라컨투어크림', '바이탈하이드라솔루션바이옴모이스처크림', '바이탈하이드라솔루션바이옴워터', '바이탈하이드라솔루션바이옴토너', '브이세븐래디언스토너', '브이세븐비타레이저', '브이세븐샤이닝라이트', '브이세븐클렌징폼', '브이세븐토너', '브이세븐토닝라이트', '브이세븐핑크토닝', '세라마이딘리퀴드', '세라마이딘오일밤', '세라마이딘크림', '세라마이딘크림미스트', '시카페어나이트리페어', '시카페어리커버', '시카페어카밍선프로텍터', '시카페어카밍젤크림', '시카페어토너', '시카페어페이셜카밍미스트', '에브리선데이마일드선', '에브리선데이모이스처라이징선', '에브리선데이선블록', '에브리선데이선스틱', '에브리선데이선플루이드', '에브리선데이톤업선스크린', '워터드롭하이드레이팅모이스처라이저', '컨트롤에이센스티브선프로텍터', '컨트롤에이수딩모이스처라이저', '컨트롤에이티트리먼트모이스처라이저', '컨트롤에이티트리먼트클렌징폼', '컨트롤에이티트리먼트토너', '포맨스크럽폼']

# %%
path1 = "./djart/{}".format(drjart[0])
file_list1 = os.listdir(path1)

# file_list_jpg = [file for file in file_list1 if file.endswith(".jpg")]
# print ("file_list: {}".format(file_list_jpg))
file_list_jpg = [file for file in file_list1 if file.endswith(".jpg") ]
print ("file_list: {}".format(file_list_jpg))
# Out:
# file_list: ['000000.jpg', '000001.jpg', '000002.jpg', '000003.jpg']

# %%
file_list_jpg[0].split('.')[0]
# Out:
# '000000'

# %%
image = cv2.imread(path1+'/'+'{0}'.format(file_list_jpg[0]))
plt.imshow(image)

# %%
image = cv2.imread(path1+'/'+'{0}'.format(file_list_jpg[0]))
image_gs=cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
faces=face_cascade.detectMultiScale(image_gs, scaleFactor=1.1, minNeighbors=1, minSize=(150, 150))
list(faces)
# Out:
# []

# %%
for i in range(len(drjart)):

    path1 = "./djart/{}".format(drjart[i])
    file_list1 = os.listdir(path1)

    # file_list_jpg = [file for file in file_list1 if file.endswith(".jpg")]
    # print ("file_list: {}".format(file_list_jpg))
    file_list_jpg = [file for file in file_list1 if file.endswith(".jpg") ]
    for i in range(len(file_list_jpg)):
        image = cv2.imread(path1+'/'+'{0}'.format(file_list_jpg[i]))
        image_gs=cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        faces1=len(face_cascade1.detectMultiScale(image_gs, scaleFactor=1.1, minNeighbors=5, minSize=(150, 150)))
        faces2=len(face_cascade2.detectMultiScale(image_gs, scaleFactor=1.1, minNeighbors=5, minSize=(150, 150))) 
#         faces3=len(face_cascade3.detectMultiScale(image_gs, scaleFactor=1.1, minNeighbors=5, minSize=(150, 150)))
#         faces4=len(face_cascade4.detectMultiScale(image_gs, scaleFactor=1.1, minNeighbors=5, minSize=(150, 150)))
#         faces5=len(face_cascade5.detectMultiScale(image_gs, scaleFactor=1.1, minNeighbors=5, minSize=(150, 150)))
#         faces6=len(face_cascade6.detectMultiScale(image_gs, scaleFactor=1.1, minNeighbors=5, minSize=(150, 150)))
#         faces7=len(face_cascade7.detectMultiScale(image_gs, scaleFactor=1.1, minNeighbors=5, minSize=(150, 150)))
        if sum([faces1,faces2])>0:
            shutil.move(path1+'/'+'{0}'.format(file_list_jpg[i]),path1+'/face/'+'{0}'.format(file_list_jpg[i])) 
#         if faces2>0:
#             shutil.move(path1+'/'+'{0}'.format(file_list_jpg[i]),path1+'/face/'+'{0}'.format(file_list_jpg[i]))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-101-163e6b860ca6> in <module>
#       2
#       3     path1 = "./djart/{}".format(drjart[i])
# ----> 4     file_list1 = os.listdir(path1)
#       5
#       6     # file_list_jpg = [file for file in file_list1 if file.endswith(".jpg")]
#
# FileNotFoundError: [WinError 3] 지정된 경로를 찾을 수 없습니다: './djart/37'

# %%
for i in range(len(drjart)):

    path1 = "./djart/{}".format(drjart[i])
    file_list1 = os.listdir(path1)

    # file_list_jpg = [file for file in file_list1 if file.endswith(".jpg")]
    # print ("file_list: {}".format(file_list_jpg))
    file_list_jpg = [file for file in file_list1 if file.endswith(".jpg") ]
    for i in range(len(file_list_jpg)):
        image = cv2.imread(path1+'/'+'{0}'.format(file_list_jpg[i]))
        image_gs=cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        eye=len(face_cascade8.detectMultiScale(image_gs, scaleFactor=1.1, minNeighbors=10, minSize=(150, 150)))
        faces1=len(face_cascade1.detectMultiScale(image_gs, scaleFactor=1.1, minNeighbors=10, minSize=(150, 150)))
        faces2=len(face_cascade2.detectMultiScale(image_gs, scaleFactor=1.1, minNeighbors=10, minSize=(150, 150))) 
        faces3=len(face_cascade3.detectMultiScale(image_gs, scaleFactor=1.1, minNeighbors=10, minSize=(150, 150)))
        #    faces4=len(face_cascade4.detectMultiScale(image_gs, scaleFactor=1.1, minNeighbors=1, minSize=(150, 150)))
        #    faces5=len(face_cascade5.detectMultiScale(image_gs, scaleFactor=1.1, minNeighbors=1, minSize=(150, 150)))
        #    faces6=len(face_cascade6.detectMultiScale(image_gs, scaleFactor=1.1, minNeighbors=1, minSize=(150, 150)))
        #    faces7=len(face_cascade7.detectMultiScale(image_gs, scaleFactor=1.1, minNeighbors=1, minSize=(150, 150)))
        #     if sum([faces1,faces2,faces3,faces4,faces5,faces6,faces7])>0:
        #         shutil.move(path1+'/'+'{0}'.format(file_list_jpg[i]),path1+'/face/'+'{0}'.format(file_list_jpg[i])) 
        if sum([eye,faces1,faces2,faces3])>0:
            shutil.move(path1+'/'+'{0}'.format(file_list_jpg[i]),path1+'/face/'+'{0}'.format(file_list_jpg[i]))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-e41f121f53dc> in <module>
#       2
#       3     path1 = "./djart/{}".format(drjart[i])
# ----> 4     file_list1 = os.listdir(path1)
#       5
#       6     # file_list_jpg = [file for file in file_list1 if file.endswith(".jpg")]
#
# FileNotFoundError: [WinError 3] 지정된 경로를 찾을 수 없습니다: './djart/37'

# %%
path1+'/'+file_list_jpg[4]
# Out:
# './djart/더마클리어마이크로약산성폼/000011.png'

# %%
image = cv2.imread('C:/Users/user/KHU/project/imagecv/djart/더마클리어마이크로약산성폼/000000.jpg')
plt.figure(figsize=(12,8))
plt.imshow(image)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-78-53767a078612> in <module>
#       1 image = cv2.imread('C:/Users/user/KHU/project/imagecv/djart/더마클리어마이크로약산성폼/000000.jpg')
# ----> 2 cv2.imshow('image',image)
#
# error: OpenCV(4.1.0) C:\projects\opencv-python\opencv\modules\highgui\src\window.cpp:352: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'

# %%
path = "./djart"
file_list = os.listdir(path)
print ("file_list: {}".format(file_list))
# Out:
# file_list: ['더마클리어마이크로약산성폼', '더마클리어마이크로워터', '더마클리어마이크로폼', '리프트라컨투어크림', '바이탈하이드라솔루션바이옴모이스처크림', '바이탈하이드라솔루션바이옴워터', '바이탈하이드라솔루션바이옴토너', '브이세븐래디언스토너', '브이세븐비타레이저', '브이세븐샤이닝라이트', '브이세븐클렌징폼', '브이세븐토너', '브이세븐토닝라이트', '브이세븐핑크토닝', '세라마이딘리퀴드', '세라마이딘오일밤', '세라마이딘크림', '세라마이딘크림미스트', '시카페어나이트리페어', '시카페어리커버', '시카페어카밍선프로텍터', '시카페어카밍젤크림', '시카페어토너', '시카페어페이셜카밍미스트', '에브리선데이마일드선', '에브리선데이모이스처라이징선', '에브리선데이선블록', '에브리선데이선스틱', '에브리선데이선플루이드', '에브리선데이톤업선스크린', '워터드롭하이드레이팅모이스처라이저', '컨트롤에이센스티브선프로텍터', '컨트롤에이수딩모이스처라이저', '컨트롤에이티트리먼트모이스처라이저', '컨트롤에이티트리먼트클렌징폼', '컨트롤에이티트리먼트토너', '포맨스크럽폼']

# %%
input_path_1 = r'./djart'

file_list= os.listdir(input_path_1)

# %%
drjart=pd.read_csv('./drjart_total.csv',encoding='cp949',index_col=0)
drjart=drjart['filename']

# %%
for i in range(len(file_list)):
    os.rename(r'C:/Users/user/KHU/project/imagecv/djart/{0}'.format(file_list[i]),
              r'C:/Users/user/KHU/project/imagecv/djart/{0}'.format(drjart[i]))

# %%
for i in range(len(drjart)):
    os.mkdir(r'C:/Users/user/KHU/project/imagecv/djart/{0}'.format(drjart[i])+'/'+'face'+'/')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-25a12ffc9169> in <module>
#       1 for i in range(len(drjart)):
# ----> 2     os.mkdir(r'C:/Users/user/KHU/project/imagecv/djart/{0}'.format(drjart[i])+'/'+'face'+'/')
#
# FileNotFoundError: [WinError 3] 지정된 경로를 찾을 수 없습니다: 'C:/Users/user/KHU/project/imagecv/djart/37/face/'

# %%
input_path_1+'/'+file_list[0]
# Out:
# './djart/더마클리어마이크로약산성폼'
